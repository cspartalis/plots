# %%
from matplotlib_venn import venn3, venn3_circles
import matplotlib.pyplot as plt

# %%
# Define the sizes of both sets and their intersection
# Define the set sizes and the intersection sizes
set_E = 25
set_P = 28
set_S = 10
intersection_EP = 17
intersection_ES = 7
intersection_PS = 6
intersection_EPS = 4

venn3(subsets = (set_E, set_P, set_S, intersection_EP, intersection_ES, intersection_PS, intersection_EPS), 
      set_labels = ('Explainability', 'Privacy', 'Security'))

plt.show()
